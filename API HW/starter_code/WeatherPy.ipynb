# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#!pip install citipy
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 587

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={api_key}&q="

city_two = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# set initial count quantities for organization
count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_two.append(city)
        else:
            count_one += 1
            city_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Processing Record 1 of Set 1 | sao felix do xingu
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | saskylakh
# City not found. Skipping...
# Processing Record 4 of Set 1 | longyearbyen
# Processing Record 5 of Set 1 | boyolangu
# Processing Record 6 of Set 1 | belgaum
# Processing Record 7 of Set 1 | eyl
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 8 of Set 1 | kavieng
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | isangel
# Processing Record 11 of Set 1 | idaho falls
# Processing Record 12 of Set 1 | talnakh
# Processing Record 13 of Set 1 | chicama
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | esperance
# Processing Record 17 of Set 1 | arandis
# City not found. Skipping...
# Processing Record 18 of Set 1 | dingle
# City not found. Skipping...
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | port shepstone
# Processing Record 22 of Set 1 | bourail
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | mahebourg
# City not found. Skipping...
# Processing Record 25 of Set 1 | camaqua
# Processing Record 26 of Set 1 | hay river
# Processing Record 27 of Set 1 | hobyo
# Processing Record 28 of Set 1 | otane
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | vao
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 31 of Set 1 | taltal
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | portland
# Processing Record 34 of Set 1 | kapaa
# Processing Record 35 of Set 1 | chuy
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | gizo
# Processing Record 38 of Set 1 | mar del plata
# City not found. Skipping...
# Processing Record 39 of Set 1 | yulara
# Processing Record 40 of Set 1 | chernyshevsk
# Processing Record 41 of Set 1 | evensk
# City not found. Skipping...
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | hithadhoo
# Processing Record 44 of Set 1 | port alfred
# Processing Record 45 of Set 1 | sapouy
# City not found. Skipping...
# Processing Record 46 of Set 1 | hensall
# Processing Record 47 of Set 1 | tanda
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | saint-philippe
# Processing Record 1 of Set 2 | namatanai
# Processing Record 2 of Set 2 | avarua
# Processing Record 3 of Set 2 | fortuna
# Processing Record 4 of Set 2 | tiarei
# Processing Record 5 of Set 2 | cherskiy
# Processing Record 6 of Set 2 | porterville
# City not found. Skipping...
# Processing Record 7 of Set 2 | edd
# Processing Record 8 of Set 2 | sisimiut
# Processing Record 9 of Set 2 | mackay
# Processing Record 10 of Set 2 | ongwediva
# Processing Record 11 of Set 2 | amapa
# Processing Record 12 of Set 2 | lorengau
# Processing Record 13 of Set 2 | pontes e lacerda
# City not found. Skipping...
# Processing Record 14 of Set 2 | broome
# Processing Record 15 of Set 2 | bluff
# Processing Record 16 of Set 2 | kaeo
# City not found. Skipping...
# Processing Record 17 of Set 2 | charters towers
# Processing Record 18 of Set 2 | bambous virieux
# Processing Record 19 of Set 2 | doha
# Processing Record 20 of Set 2 | kattivakkam
# Processing Record 21 of Set 2 | provideniya
# Processing Record 22 of Set 2 | hamilton
# Processing Record 23 of Set 2 | tessalit
# Processing Record 24 of Set 2 | kaitangata
# Processing Record 25 of Set 2 | hilo
# Processing Record 26 of Set 2 | almaznyy
# Processing Record 27 of Set 2 | potam
# Processing Record 28 of Set 2 | saldanha
# City not found. Skipping...
# Processing Record 29 of Set 2 | naguabo
# Processing Record 30 of Set 2 | naze
# Processing Record 31 of Set 2 | geraldton
# Processing Record 32 of Set 2 | huarmey
# Processing Record 33 of Set 2 | albany
# Processing Record 34 of Set 2 | hobart
# Processing Record 35 of Set 2 | san patricio
# Processing Record 36 of Set 2 | khatanga
# Processing Record 37 of Set 2 | flinders
# Processing Record 38 of Set 2 | gejiu
# Processing Record 39 of Set 2 | grand river south east
# Processing Record 40 of Set 2 | zapolyarnyy
# Processing Record 41 of Set 2 | fort saint john
# Processing Record 42 of Set 2 | yumen
# Processing Record 43 of Set 2 | kysyl-syr
# Processing Record 44 of Set 2 | lagoa
# Processing Record 45 of Set 2 | namibe
# Processing Record 46 of Set 2 | port elizabeth
# Processing Record 47 of Set 2 | chulman
# Processing Record 48 of Set 2 | pevek
# Processing Record 49 of Set 2 | phonhong
# Processing Record 1 of Set 3 | luderitz
# Processing Record 2 of Set 3 | tuktoyaktuk
# Processing Record 3 of Set 3 | jamestown
# Processing Record 4 of Set 3 | kralendijk
# Processing Record 5 of Set 3 | port hardy
# Processing Record 6 of Set 3 | morelia
# Processing Record 7 of Set 3 | new norfolk
# Processing Record 8 of Set 3 | mataura
# Processing Record 9 of Set 3 | chapais
# City not found. Skipping...
# Processing Record 10 of Set 3 | victoria
# Processing Record 11 of Set 3 | ahipara
# City not found. Skipping...
# Processing Record 12 of Set 3 | saint-augustin
# Processing Record 13 of Set 3 | menongue
# Processing Record 14 of Set 3 | chokurdakh
# Processing Record 15 of Set 3 | sitka
# Processing Record 16 of Set 3 | torbay
# Processing Record 17 of Set 3 | fairbanks
# Processing Record 18 of Set 3 | hasaki
# Processing Record 19 of Set 3 | fort nelson
# Processing Record 20 of Set 3 | cabo san lucas
# Processing Record 21 of Set 3 | ludvika
# Processing Record 22 of Set 3 | mayo
# City not found. Skipping...
# Processing Record 23 of Set 3 | agua verde
# Processing Record 24 of Set 3 | norman wells
# Processing Record 25 of Set 3 | vostok
# Processing Record 26 of Set 3 | georgetown
# Processing Record 27 of Set 3 | airai
# Processing Record 28 of Set 3 | touros
# Processing Record 29 of Set 3 | narsaq
# Processing Record 30 of Set 3 | barrow
# Processing Record 31 of Set 3 | san lorenzo
# Processing Record 32 of Set 3 | yarkovo
# Processing Record 33 of Set 3 | agadez
# Processing Record 34 of Set 3 | aksu
# Processing Record 35 of Set 3 | nikolskoye
# Processing Record 36 of Set 3 | lompoc
# Processing Record 37 of Set 3 | konstancin-jeziorna
# Processing Record 38 of Set 3 | cidreira
# Processing Record 39 of Set 3 | bandarbeyla
# Processing Record 40 of Set 3 | berdigestyakh
# Processing Record 41 of Set 3 | homer
# Processing Record 42 of Set 3 | high level
# Processing Record 43 of Set 3 | tilichiki
# Processing Record 44 of Set 3 | tasiilaq
# Processing Record 45 of Set 3 | pangnirtung
# Processing Record 46 of Set 3 | bam
# Processing Record 47 of Set 3 | verkhnyaya maksakovka
# Processing Record 48 of Set 3 | paralimni
# City not found. Skipping...
# Processing Record 49 of Set 3 | havre-saint-pierre
# Processing Record 1 of Set 4 | ponta do sol
# Processing Record 2 of Set 4 | tual
# Processing Record 3 of Set 4 | xichang
# Processing Record 4 of Set 4 | nemuro
# Processing Record 5 of Set 4 | rocha
# Processing Record 6 of Set 4 | tuatapere
# Processing Record 7 of Set 4 | bethel
# Processing Record 8 of Set 4 | pisco
# Processing Record 9 of Set 4 | aklavik
# Processing Record 10 of Set 4 | thompson
# Processing Record 11 of Set 4 | marsh harbour
# Processing Record 12 of Set 4 | clyde river
# Processing Record 13 of Set 4 | camacha
# Processing Record 14 of Set 4 | sao filipe
# Processing Record 15 of Set 4 | dalby
# Processing Record 16 of Set 4 | port hedland
# Processing Record 17 of Set 4 | mataram
# Processing Record 18 of Set 4 | sikasso
# Processing Record 19 of Set 4 | codrington
# Processing Record 20 of Set 4 | salalah
# Processing Record 21 of Set 4 | mizdah
# Processing Record 22 of Set 4 | baykit
# Processing Record 23 of Set 4 | basar
# Processing Record 24 of Set 4 | mildura
# City not found. Skipping...
# Processing Record 25 of Set 4 | mahibadhoo
# Processing Record 26 of Set 4 | brookings
# Processing Record 27 of Set 4 | canutama
# Processing Record 28 of Set 4 | esmeraldas
# Processing Record 29 of Set 4 | havelock
# Processing Record 30 of Set 4 | hearst
# Processing Record 31 of Set 4 | kavaratti
# Processing Record 32 of Set 4 | qaanaaq
# Processing Record 33 of Set 4 | haines junction
# Processing Record 34 of Set 4 | meadow lake
# Processing Record 35 of Set 4 | ipilan
# Processing Record 36 of Set 4 | soe
# Processing Record 37 of Set 4 | kokopo
# Processing Record 38 of Set 4 | ranfurly
# Processing Record 39 of Set 4 | nokaneng
# Processing Record 40 of Set 4 | bang saphan
# City not found. Skipping...
# Processing Record 41 of Set 4 | kodiak
# Processing Record 42 of Set 4 | atar
# Processing Record 43 of Set 4 | ugoofaaru
# Processing Record 44 of Set 4 | zyryanka
# Processing Record 45 of Set 4 | cedar city
# Processing Record 46 of Set 4 | carnarvon
# Processing Record 47 of Set 4 | shenjiamen
# Processing Record 48 of Set 4 | misratah
# Processing Record 49 of Set 4 | souillac
# Processing Record 1 of Set 5 | mulanje
# Processing Record 2 of Set 5 | nizwa
# Processing Record 3 of Set 5 | noumea
# City not found. Skipping...
# Processing Record 4 of Set 5 | berlevag
# Processing Record 5 of Set 5 | cabedelo
# Processing Record 6 of Set 5 | dikson
# Processing Record 7 of Set 5 | priseaca
# Processing Record 8 of Set 5 | dunedin
# Processing Record 9 of Set 5 | marovoay
# Processing Record 10 of Set 5 | qingdao
# Processing Record 11 of Set 5 | buchanan
# Processing Record 12 of Set 5 | san quintin
# Processing Record 13 of Set 5 | morehead
# Processing Record 14 of Set 5 | necochea
# Processing Record 15 of Set 5 | harindanga
# Processing Record 16 of Set 5 | komsomolskiy
# Processing Record 17 of Set 5 | faya
# Processing Record 18 of Set 5 | samfya
# Processing Record 19 of Set 5 | grand centre
# Processing Record 20 of Set 5 | leningradskiy
# Processing Record 21 of Set 5 | awbari
# Processing Record 22 of Set 5 | simao
# Processing Record 23 of Set 5 | waddan
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 24 of Set 5 | barmer
# Processing Record 25 of Set 5 | ribeira grande
# Processing Record 26 of Set 5 | vestmanna
# Processing Record 27 of Set 5 | east london
# Processing Record 28 of Set 5 | okhotsk
# Processing Record 29 of Set 5 | marystown
# Processing Record 30 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 5 | saint-pierre
# Processing Record 32 of Set 5 | whyalla
# Processing Record 33 of Set 5 | corning
# City not found. Skipping...
# Processing Record 34 of Set 5 | jacksonville
# Processing Record 35 of Set 5 | bethanien
# Processing Record 36 of Set 5 | nhulunbuy
# Processing Record 37 of Set 5 | fayaoue
# Processing Record 38 of Set 5 | valera
# Processing Record 39 of Set 5 | beira
# City not found. Skipping...
# Processing Record 40 of Set 5 | ulladulla
# Processing Record 41 of Set 5 | pabrade
# Processing Record 42 of Set 5 | bonthe
# Processing Record 43 of Set 5 | puerto pinasco
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 44 of Set 5 | santiago del estero
# Processing Record 45 of Set 5 | alta
# Processing Record 46 of Set 5 | lebu
# City not found. Skipping...
# Processing Record 47 of Set 5 | brae
# Processing Record 48 of Set 5 | arraial do cabo
# Processing Record 49 of Set 5 | sabancuy
# Processing Record 1 of Set 6 | klaksvik
# Processing Record 2 of Set 6 | rosarito
# Processing Record 3 of Set 6 | nanortalik
# Processing Record 4 of Set 6 | kruisfontein
# Processing Record 5 of Set 6 | castro
# Processing Record 6 of Set 6 | colares
# Processing Record 7 of Set 6 | brus
# Processing Record 8 of Set 6 | nicoya
# City not found. Skipping...
# Processing Record 9 of Set 6 | mecca
# Processing Record 10 of Set 6 | luganville
# Processing Record 11 of Set 6 | byron bay
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 12 of Set 6 | birao
# Processing Record 13 of Set 6 | pandoh
# Processing Record 14 of Set 6 | mitsamiouli
# City not found. Skipping...
# Processing Record 15 of Set 6 | udachnyy
# City not found. Skipping...
# Processing Record 16 of Set 6 | ferrol
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 17 of Set 6 | katsuura
# Processing Record 18 of Set 6 | shieli
# Processing Record 19 of Set 6 | quimper
# City not found. Skipping...
# Processing Record 20 of Set 6 | yar-sale
# Processing Record 21 of Set 6 | springbok
# Processing Record 22 of Set 6 | nigde
# Processing Record 23 of Set 6 | husavik
# Processing Record 24 of Set 6 | baoning
# Processing Record 25 of Set 6 | acapulco
# Processing Record 26 of Set 6 | kungurtug
# Processing Record 27 of Set 6 | sinnamary
# Processing Record 28 of Set 6 | auki
# Processing Record 29 of Set 6 | xining
# Processing Record 30 of Set 6 | mahesana
# Processing Record 31 of Set 6 | aykhal
# City not found. Skipping...
# Processing Record 32 of Set 6 | sal rei
# Processing Record 33 of Set 6 | kamaishi
# Processing Record 34 of Set 6 | saint-paul
# Processing Record 35 of Set 6 | panshi
# Processing Record 36 of Set 6 | lure
# Processing Record 37 of Set 6 | palora
# City not found. Skipping...
# Processing Record 38 of Set 6 | oxbow
# Processing Record 39 of Set 6 | buncrana
# Processing Record 40 of Set 6 | aksha
# Processing Record 41 of Set 6 | bitung
# City not found. Skipping...
# Processing Record 42 of Set 6 | belaya gora
# City not found. Skipping...
# Processing Record 43 of Set 6 | amethi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 44 of Set 6 | chongwe
# Processing Record 45 of Set 6 | nosy varika
# City not found. Skipping...
# Processing Record 46 of Set 6 | stulovo
# Processing Record 47 of Set 6 | coahuayana
# Processing Record 48 of Set 6 | qasigiannguit
# Processing Record 49 of Set 6 | samarai
# Processing Record 1 of Set 7 | beringovskiy
# Processing Record 2 of Set 7 | antalaha
# Processing Record 3 of Set 7 | muzhi
# Processing Record 4 of Set 7 | nouadhibou
# Processing Record 5 of Set 7 | sioux lookout
# Processing Record 6 of Set 7 | constitucion
# Processing Record 7 of Set 7 | nacozari
# Processing Record 8 of Set 7 | lavrentiya
# Processing Record 9 of Set 7 | shambu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 10 of Set 7 | zhigansk
# Processing Record 11 of Set 7 | rock springs
# Processing Record 12 of Set 7 | kirakira
# City not found. Skipping...
# Processing Record 13 of Set 7 | padang
# Processing Record 14 of Set 7 | puerto madryn
# Processing Record 15 of Set 7 | ust-kuyga
# Processing Record 16 of Set 7 | sibu
# Processing Record 17 of Set 7 | yangambi
# Processing Record 18 of Set 7 | wollongong
# Processing Record 19 of Set 7 | oxford
# City not found. Skipping...
# Processing Record 20 of Set 7 | hundested
# Processing Record 21 of Set 7 | brownfield
# Processing Record 22 of Set 7 | thayetmyo
# Processing Record 23 of Set 7 | mount gambier
# Processing Record 24 of Set 7 | guarapari
# City not found. Skipping...
# Processing Record 25 of Set 7 | vila velha
# City not found. Skipping...
# Processing Record 26 of Set 7 | lumeje
# Processing Record 27 of Set 7 | pollachi
# Processing Record 28 of Set 7 | aripuana
# Processing Record 29 of Set 7 | shingu
# Processing Record 30 of Set 7 | muros
# City not found. Skipping...
# Processing Record 31 of Set 7 | alofi
# Processing Record 32 of Set 7 | gryazovets
# Processing Record 33 of Set 7 | severo-kurilsk
# Processing Record 34 of Set 7 | upernavik
# Processing Record 35 of Set 7 | santana
# Processing Record 36 of Set 7 | roma
# Processing Record 37 of Set 7 | araouane
# Processing Record 38 of Set 7 | bathsheba
# Processing Record 39 of Set 7 | kununurra
# City not found. Skipping...
# Processing Record 40 of Set 7 | qaqortoq
# Processing Record 41 of Set 7 | grand gaube
# Processing Record 42 of Set 7 | tarakan
# Processing Record 43 of Set 7 | adrar
# City not found. Skipping...
# Processing Record 44 of Set 7 | fairlie
# Processing Record 45 of Set 7 | douglas
# Processing Record 46 of Set 7 | carnot
# Processing Record 47 of Set 7 | taoudenni
# Processing Record 48 of Set 7 | hami
# Processing Record 49 of Set 7 | odienne
# Processing Record 1 of Set 8 | grindavik
# Processing Record 2 of Set 8 | chase
# Processing Record 3 of Set 8 | radhanpur
# Processing Record 4 of Set 8 | wanning
# Processing Record 5 of Set 8 | buta
# City not found. Skipping...
# Processing Record 6 of Set 8 | maumere
# Processing Record 7 of Set 8 | okha
# Processing Record 8 of Set 8 | taguatinga
# Processing Record 9 of Set 8 | marawi
# Processing Record 10 of Set 8 | bonfim
# Processing Record 11 of Set 8 | san policarpo
# Processing Record 12 of Set 8 | ancud
# Processing Record 13 of Set 8 | praia
# City not found. Skipping...
# Processing Record 14 of Set 8 | arklow
# Processing Record 15 of Set 8 | xiamen
# Processing Record 16 of Set 8 | seabra
# Processing Record 17 of Set 8 | yazman
# City not found. Skipping...
# Processing Record 18 of Set 8 | san cristobal
# City not found. Skipping...
# Processing Record 19 of Set 8 | hofn
# Processing Record 20 of Set 8 | oussouye
# Processing Record 21 of Set 8 | tiksi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 22 of Set 8 | puerto del rosario
# Processing Record 23 of Set 8 | isla mujeres
# Processing Record 24 of Set 8 | ulaanbaatar
# Processing Record 25 of Set 8 | tsumeb
# Processing Record 26 of Set 8 | solnechnyy
# Processing Record 27 of Set 8 | yanam
# Processing Record 28 of Set 8 | svecha
# Processing Record 29 of Set 8 | fukue
# City not found. Skipping...
# Processing Record 30 of Set 8 | kaili
# Processing Record 31 of Set 8 | daru
# Processing Record 32 of Set 8 | hirara
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of Set 8 | sambava
# Processing Record 34 of Set 8 | san francisco
# Processing Record 35 of Set 8 | pervomayskoye
# Processing Record 36 of Set 8 | ponta delgada
# Processing Record 37 of Set 8 | iqaluit
# Processing Record 38 of Set 8 | ola
# Processing Record 39 of Set 8 | banda aceh
# Processing Record 40 of Set 8 | srednekolymsk
# City not found. Skipping...
# Processing Record 41 of Set 8 | faanui
# Processing Record 42 of Set 8 | jaca
# Processing Record 43 of Set 8 | vega de alatorre
# Processing Record 44 of Set 8 | puro
# Processing Record 45 of Set 8 | merauke
# Processing Record 46 of Set 8 | ortona
# Processing Record 47 of Set 8 | katima mulilo
# Processing Record 48 of Set 8 | benghazi
# Processing Record 49 of Set 8 | havoysund
# City not found. Skipping...
# Processing Record 1 of Set 9 | pochutla
# Processing Record 2 of Set 9 | lasa
# Processing Record 3 of Set 9 | nishihara
# City not found. Skipping...
# Processing Record 4 of Set 9 | black river
# Processing Record 5 of Set 9 | huesca
# Processing Record 6 of Set 9 | ust-omchug
# Processing Record 7 of Set 9 | deputatskiy
# Processing Record 8 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 9 | aktau
# Processing Record 10 of Set 9 | bemidji
# Processing Record 11 of Set 9 | kieta
# Processing Record 12 of Set 9 | puerto suarez
# Processing Record 13 of Set 9 | zhangjiakou
# Processing Record 14 of Set 9 | fallon
# Processing Record 15 of Set 9 | havre
# Processing Record 16 of Set 9 | inhambane
# Processing Record 17 of Set 9 | miri
# City not found. Skipping...
# Processing Record 18 of Set 9 | karsava
# Processing Record 19 of Set 9 | lumajang
# City not found. Skipping...
# Processing Record 20 of Set 9 | awjilah
# Processing Record 21 of Set 9 | labuhan
# Processing Record 22 of Set 9 | ranong
# Processing Record 23 of Set 9 | kayes
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 24 of Set 9 | gavle
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 25 of Set 9 | thinadhoo
# Processing Record 26 of Set 9 | ambilobe
# City not found. Skipping...
# Processing Record 27 of Set 9 | rockport
# City not found. Skipping...
# Processing Record 28 of Set 9 | tura
# Processing Record 29 of Set 9 | ashcroft
# Processing Record 30 of Set 9 | poronaysk
# Processing Record 31 of Set 9 | coihaique
# Processing Record 32 of Set 9 | karratha
# Processing Record 33 of Set 9 | zheleznodorozhnyy
# Processing Record 34 of Set 9 | gravdal
# City not found. Skipping...
# Processing Record 35 of Set 9 | urucui
# Processing Record 36 of Set 9 | kushima
# Processing Record 37 of Set 9 | kollam
# City not found. Skipping...
# Processing Record 38 of Set 9 | zharkent
# Processing Record 39 of Set 9 | baikunthpur
# Processing Record 40 of Set 9 | ikwiriri
# Processing Record 41 of Set 9 | sao jose de ribamar
# Processing Record 42 of Set 9 | porangatu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of Set 9 | chimbote
# Processing Record 44 of Set 9 | khorinsk
# Processing Record 45 of Set 9 | phichit
# Processing Record 46 of Set 9 | orlik

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City":city_two,
    "Cloudiness":cloudinesses,
    "Country":countries,
    "Date":dates,
    "Humidity":humidities,
    "Lat":lats,
    "Lng":lngs,
    "Max Temp":max_temps,
    "Wind Speed":wind_speeds
}
weather_dataframe = pd.DataFrame(weather_dict)

weather_dataframe.count()

# %%
weather_dataframe.head()

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Max Temp"],edgecolors="black",facecolors="blue")
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("../Images/plot1.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Humidity"],edgecolors="black",facecolors="blue")
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(15,105)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("../Images/plot2.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Cloudiness"],edgecolors="black",facecolors="blue")
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("../Images/plot3.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Wind Speed"],edgecolors="black",facecolors="blue")
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(-2,34)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("../Images/plot4.png")
plt.show()

# %% [markdown]
# Observable Trends:
#
# 1.There is no identifiable correlation between cloudiness and latitude.
# 2. As latitutde approaches 0, the temparature increases.
# 3. At about 0 lattitude, humidty is primarily at a maximum 100%; other than at 0, there is no correlation between humidity and latitude.
